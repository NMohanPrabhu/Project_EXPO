# %% [markdown]
# <font color="blue" size ="6"><b>WELCOME TO PROJECT EXPO</b></font>

# %% [markdown]
# <font color="yellow" size="4"><b>2_Classfication_Diabetes </b></font>

# %%
# Step 2: Import libraries
import pandas as pd
from pycaret.classification import *

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Step 4: Initialize PyCaret setup
clf = setup(
    data=df, 
    target=df['Outcome'], 
    session_id=42, 
    normalize=True, 
    )
# Out:
# <style type="text/css">
# #T_e0e57_row8_col1, #T_e0e57_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e0e57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0e57_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e0e57_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0e57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0e57_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e0e57_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_e0e57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0e57_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e0e57_row1_col1" class="data row1 col1" >Outcome_y</td>
#     </tr>
#     <tr>
#       <th id="T_e0e57_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Step 5: Compare models (AutoML)
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_27ae6 th {
#   text-align: left;
# }
# #T_27ae6_row0_col0, #T_27ae6_row1_col0, #T_27ae6_row2_col0, #T_27ae6_row3_col0, #T_27ae6_row4_col0, #T_27ae6_row5_col0, #T_27ae6_row6_col0, #T_27ae6_row7_col0, #T_27ae6_row8_col0, #T_27ae6_row9_col0, #T_27ae6_row10_col0, #T_27ae6_row11_col0, #T_27ae6_row12_col0, #T_27ae6_row13_col0, #T_27ae6_row14_col0, #T_27ae6_row14_col1, #T_27ae6_row14_col2, #T_27ae6_row14_col3, #T_27ae6_row14_col4, #T_27ae6_row14_col5, #T_27ae6_row14_col6, #T_27ae6_row14_col7, #T_27ae6_row15_col0, #T_27ae6_row15_col1, #T_27ae6_row15_col2, #T_27ae6_row15_col3, #T_27ae6_row15_col4, #T_27ae6_row15_col5, #T_27ae6_row15_col6, #T_27ae6_row15_col7 {
#   text-align: left;
# }
# ...

# %%
#Analyze Model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#Save Model
save_model(best_model, 'diabetes_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'SkinThickness',
#                                               'Insulin', 'BMI',
#                                               'DiabetesPedigreeFunction', 'Age',
#                                               'Outcome_x'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
# ...

# %%
# load pipeline
loaded_best_pipeline = load_model('diabetes_pipeline')
loaded_best_pipeline
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=C:\Users\ADMINI~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Pregnancies', 'Glucose',
#                                              'BloodPressure', 'SkinThickness',
#                                              'Insulin', 'BMI',
#                                              'DiabetesPedigreeFunction', 'Age',
#                                              'Outcome_x'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty...
#                  TransformerWrapper(exclude=None, include=None,
# ...

# %%
# create gradio app
create_app(best_model)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
